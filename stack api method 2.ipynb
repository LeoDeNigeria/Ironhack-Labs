# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
pip install stackapi
# Out:
# Requirement already satisfied: stackapi in c:\users\osile\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: six in c:\users\osile\anaconda3\lib\site-packages (from stackapi) (1.16.0)
# Requirement already satisfied: requests in c:\users\osile\anaconda3\lib\site-packages (from stackapi) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\osile\anaconda3\lib\site-packages (from requests->stackapi) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\osile\anaconda3\lib\site-packages (from requests->stackapi) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\osile\anaconda3\lib\site-packages (from requests->stackapi) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\osile\anaconda3\lib\site-packages (from requests->stackapi) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
from stackapi import StackAPI
import requests
import json

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
from stackapi import StackAPI
response=requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")
print(response.json())
# Out:
# {'items': [{'tags': ['node.js', 'tcp'], 'owner': {'account_id': 8585399, 'reputation': 353, 'user_id': 6431715, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/db440781f665b211eab6be5d7c71c0e4?s=256&d=identicon&r=PG&f=1', 'display_name': 'Zvi Vered', 'link': 'https://stackoverflow.com/users/6431715/zvi-vered'}, 'is_answered': False, 'view_count': 1, 'answer_count': 0, 'score': 0, 'last_activity_date': 1659457643, 'creation_date': 1659457643, 'question_id': 73210802, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73210802/node-js-send-raw-data-of-uint32array', 'title': 'node.js: Send raw data of Uint32Array'}, {'tags': ['r', 'cumsum'], 'owner': {'account_id': 12207969, 'reputation': 31, 'user_id': 8910493, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/cae313569a1672e8467e5180d8f4fba6?s=256&d=identicon&r=PG&f=1', 'display_name': 'Eric Tim', 'link': 'https://stackoverflow.com/users/8910493/eric-tim'}, 'is_answered': False, 'view_count': 2, 'answer_count': 0, 'score': 0, 'last_activity_date': 1659457638, 'creation_date': 1659457638, 'question_id': 73210801, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73210801/how-do-i-fix-a-cumulative-sum-in-r-when-dealing-with-negative-values', 'title': 'How do I fix a cumulative sum in R when dealing with negative values'}, {'tags': ['struct', 'mapping', 'solidity', 'smartcontracts'], 'owner': {'account_id': 25959460, 'reputation': 1, 'user_id': 19676310, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a-/AFdZucodYnjBeIW0ZNA00yJJX0XHG9uKl74k7QzrHY1-=k-s256', 'display_name': 'Jbrowser', 'link': 'https://stackoverflow.com/users/19676310/jbrowser'}, 'is_answered': False, 'view_count': 2, 'answer_count': 0, 'score': 0, 'last_activity_date': 1659457634, 'creation_date': 1659457634, 'question_id': 73210800, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73210800/how-do-i-write-a-function-that-sets-an-address-to-a-struct', 'title': 'How do I write a function that sets an address to a struct?'}, {'tags': ['node.js', 'typescript', 'postgresql'], 'owner': {'account_id': 15545975, 'reputation': 25, 'user_id': 11215188, 'user_type': 'registered', 'profile_image': 'https://lh4.googleusercontent.com/-ELWGqeRbrto/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rfQIJRvV10ttFBifr5anSQ_z4U1sA/mo/photo.jpg?sz=256', 'display_name': 'marvin ariel johannes', 'link': 'https://stackoverflow.com/users/11215188/marvin-ariel-johannes'}, 'is_answered': False, 'view_count': 2, 'answer_count': 0, 'score': 0, 'last_activity_date': 1659457634, 'creation_date': 1659457634, 'question_id': 73210799, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73210799/property-users-does-not-exist-on-type-requestparamsdictionary-any-any-par', 'title': 'Property &#39;users&#39; does not exist on type &#39;Request&lt;ParamsDictionary, any, any, ParsedQs, Record&lt;string, any&gt;&gt;&#39;. Did you mean &#39;user&#39;?'}, {'tags': ['excel', 'excel-formula'], 'owner': {'account_id': 25958839, 'reputation': 1, 'user_id': 19675789, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/70fd14cb4a71d28bf5a3fffa121eb33e?s=256&d=identicon&r=PG', 'display_name': 'soop', 'link': 'https://stackoverflow.com/users/19675789/soop'}, 'is_answered': False, 'view_count': 13, 'answer_count': 1, 'score': 0, 'last_activity_date': 1659457632, 'creation_date': 1659454591, 'last_edit_date': 1659456651, 'question_id': 73210187, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73210187/how-can-i-assign-a-value-to-names-in-excel-and-then-find-the-difference-between', 'title': 'How can I assign a value to names in Excel and then find the difference between the values?'}, {'tags': ['java', 'workflow', 'aem'], 'owner': {'account_id': 10835939, 'reputation': 1, 'user_id': 7968933, 'user_type': 'registered', 'profile_ima ...

# %%
results=(response.json())
res=response.json()
l=res["items"]
l
# Out:
# [{'tags': ['node.js', 'tcp'],
#   'owner': {'account_id': 8585399,
#    'reputation': 353,
#    'user_id': 6431715,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/db440781f665b211eab6be5d7c71c0e4?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Zvi Vered',
#    'link': 'https://stackoverflow.com/users/6431715/zvi-vered'},
#   'is_answered': False,
#   'view_count': 1,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457643,
#   'creation_date': 1659457643,
#   'question_id': 73210802,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210802/node-js-send-raw-data-of-uint32array',
#   'title': 'node.js: Send raw data of Uint32Array'},
#  {'tags': ['r', 'cumsum'],
#   'owner': {'account_id': 12207969,
#    'reputation': 31,
#    'user_id': 8910493,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/cae313569a1672e8467e5180d8f4fba6?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Eric Tim',
#    'link': 'https://stackoverflow.com/users/8910493/eric-tim'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457638,
#   'creation_date': 1659457638,
#   'question_id': 73210801,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210801/how-do-i-fix-a-cumulative-sum-in-r-when-dealing-with-negative-values',
#   'title': 'How do I fix a cumulative sum in R when dealing with negative values'},
#  {'tags': ['struct', 'mapping', 'solidity', 'smartcontracts'],
#   'owner': {'account_id': 25959460,
#    'reputation': 1,
#    'user_id': 19676310,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AFdZucodYnjBeIW0ZNA00yJJX0XHG9uKl74k7QzrHY1-=k-s256',
#    'display_name': 'Jbrowser',
#    'link': 'https://stackoverflow.com/users/19676310/jbrowser'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457634,
#   'creation_date': 1659457634,
#   'question_id': 73210800,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210800/how-do-i-write-a-function-that-sets-an-address-to-a-struct',
#   'title': 'How do I write a function that sets an address to a struct?'},
#  {'tags': ['node.js', 'typescript', 'postgresql'],
#   'owner': {'account_id': 15545975,
#    'reputation': 25,
#    'user_id': 11215188,
#    'user_type': 'registered',
#    'profile_image': 'https://lh4.googleusercontent.com/-ELWGqeRbrto/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rfQIJRvV10ttFBifr5anSQ_z4U1sA/mo/photo.jpg?sz=256',
#    'display_name': 'marvin ariel johannes',
#    'link': 'https://stackoverflow.com/users/11215188/marvin-ariel-johannes'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457634,
#   'creation_date': 1659457634,
#   'question_id': 73210799,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210799/property-users-does-not-exist-on-type-requestparamsdictionary-any-any-par',
#   'title': 'Property &#39;users&#39; does not exist on type &#39;Request&lt;ParamsDictionary, any, any, ParsedQs, Record&lt;string, any&gt;&gt;&#39;. Did you mean &#39;user&#39;?'},
#  {'tags': ['excel', 'excel-formula'],
#   'owner': {'account_id': 25958839,
#    'reputation': 1,
#    'user_id': 19675789,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/70fd14cb4a71d28bf5a3fffa121eb33e?s=256&d=identicon&r=PG',
#    'display_name': 'soop',
#    'link': 'https://stackoverflow.com/users/19675789/soop'},
#   'is_answered': False,
#   'view_count': 13,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1659457632,
#   'creation_date': 1659454591,
#   'last_edit_date': 1659456651,
#   'question_id': 73210187,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210187/how-can-i-assign-a-value-to-names-in-excel-and-then-find-the-difference-between',
#   'title': 'How can I assign a value to names in Excel and then find the difference between the values?'},
#  {'tags': ['java', 'workflow', 'aem'],
#   'owner': {'account_id': 10835939,
#    'reputation': 1,
#    'user_id': 7968933,
#    'user_type': 'registered',
#    'profile_image': 'https://lh6.googleusercontent.com/-qU9MfTIUd_M/AAAAAAAAAAI/AAAAAAAADBU/F9wtjmg9oQo/photo.jpg?sz=256',
#    'display_name': 'Mrinalini Alakananda',
#    'link': 'https://stackoverflow.com/users/7968933/mrinalini-alakananda'},
#   'is_answered': False,
#   'view_count': 138,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1659457631,
#   'creation_date': 1641469907,
#   'question_id': 70606688,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/70606688/workflow-triggered-on-replication-event-listener-looping-itself-in-aem',
#   'title': 'Workflow triggered on replication event listener looping itself in AEM'},
#  {'tags': ['python', 'python-3.x'],
#   'owner': {'account_id': 3526205,
#    'reputation': 597,
#    'user_id': 2947218,
#    'user_type': 'registered',
#    'accept_rate': 69,
#    'profile_image': 'https://i.stack.imgur.com/LI3bk.png?s=256&g=1',
#    'display_name': 'Sudipta Dhara',
#    'link': 'https://stackoverflow.com/users/2947218/sudipta-dhara'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457629,
#   'creation_date': 1659457629,
#   'question_id': 73210796,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210796/unique-combination-product-of-two-columns-from-multiple-lists-in-python-3',
#   'title': 'Unique combination/product of two columns from multiple lists in python 3'},
#  {'tags': ['pyomo'],
#   'owner': {'account_id': 14010888,
#    'reputation': 1,
#    'user_id': 10119560,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/1917596606e0743838e647067e44cc04?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Thomas Xi',
#    'link': 'https://stackoverflow.com/users/10119560/thomas-xi'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457623,
#   'creation_date': 1659457623,
#   'question_id': 73210795,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210795/pyomo-using-both-ipopt-and-baron-as-solvers',
#   'title': 'Pyomo using both IPOPT and Baron as solvers'},
#  {'tags': ['html', 'jenkins', 'post', 'request', 'pipeline'],
#   'owner': {'account_id': 24040869,
#    'reputation': 31,
#    'user_id': 19547474,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/ad1adf8417723fa8ba6c3578d93bb2d7?s=256&d=identicon&r=PG',
#    'display_name': 'eresque-',
#    'link': 'https://stackoverflow.com/users/19547474/eresque'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457622,
#   'creation_date': 1659457622,
#   'question_id': 73210794,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210794/how-to-abort-jenkins-build-using-command-line',
#   'title': 'How to abort Jenkins build using command line'},
#  {'tags': ['html', 'css', 'image'],
#   'owner': {'account_id': 25951474,
#    'reputation': 1,
#    'user_id': 19669455,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AFdZucokOky89ve2m9zddd0n0kMH5f28JKa2VuaKYDHgNA=k-s256',
#    'display_name': 'Aryan Srivastava',
#    'link': 'https://stackoverflow.com/users/19669455/aryan-srivastava'},
#   'is_answered': False,
#   'view_count': 28,
#   'answer_count': 1,
#   'score': -2,
#   'last_activity_date': 1659457622,
#   'creation_date': 1659385960,
#   'last_edit_date': 1659456956,
#   'question_id': 73199312,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73199312/why-are-these-images-not-taking-up-the-entire-space-in-the-line-but-instead-shif',
#   'title': 'Why are these images not taking up the entire space in the line but instead shifting down?'},
#  {'tags': ['python', 'mongodb', 'postman'],
#   'owner': {'account_id': 25958934,
#    'reputation': 1,
#    'user_id': 19675872,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/e3b0dfd1c6b37adce5b0cbd420dbc6ef?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Rajashekar Thota',
#    'link': 'https://stackoverflow.com/users/19675872/rajashekar-thota'},
#   'is_answered': False,
#   'view_count': 5,
#   'answer_count': 0,
#   'score': -1,
#   'last_activity_date': 1659457619,
#   'creation_date': 1659453391,
#   'last_edit_date': 1659457619,
#   'question_id': 73209934,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73209934/running-api-from-postman-and-using-studio-3t-for-mongo-db-in-postman-getting-ou',
#   'title': 'running api from postman and using studio 3t for mongo db. in postman getting output error but status is showing ok'},
#  {'tags': ['javascript', 'arrays', 'sorting'],
#   'owner': {'account_id': 25872154,
#    'reputation': 1,
#    'user_id': 19602842,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/dd590bea4b9402009495982a5b14d31a?s=256&d=identicon&r=PG',
#    'display_name': 'mew',
#    'link': 'https://stackoverflow.com/users/19602842/mew'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457616,
#   'creation_date': 1659457616,
#   'question_id': 73210792,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210792/how-to-use-sort-in-an-array',
#   'title': 'How to use .sort in an array'},
#  {'tags': ['mysql', 'sql'],
#   'owner': {'account_id': 2539892,
#    'reputation': 2876,
#    'user_id': 2205916,
#    'user_type': 'registered',
#    'accept_rate': 44,
#    'profile_image': 'https://www.gravatar.com/avatar/3d7153ce8e81b985a57ef4cbdfac2c8f?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'user2205916',
#    'link': 'https://stackoverflow.com/users/2205916/user2205916'},
#   'is_answered': False,
#   'view_count': 16,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457616,
#   'creation_date': 1659455291,
#   'last_edit_date': 1659457616,
#   'question_id': 73210355,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210355/how-to-calculate-total-distance-traveled-for-a-group-with-multiple-lat-longs-pe',
#   'title': 'How to calculate total distance traveled for a group, with multiple lat longs per group?'},
#  {'tags': ['ios', 'swift', 'xcode', 'uistackview'],
#   'owner': {'account_id': 5458637,
#    'reputation': 411,
#    'user_id': 4341372,
#    'user_type': 'registered',
#    'profile_image': 'https://graph.facebook.com/100000599615966/picture?type=large',
#    'display_name': 'Karl Mcgeough',
#    'link': 'https://stackoverflow.com/users/4341372/karl-mcgeough'},
#   'is_answered': False,
#   'view_count': 29,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457607,
#   'creation_date': 1659370379,
#   'last_edit_date': 1659457607,
#   'question_id': 73196661,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73196661/swift-uistackview-not-displaying-subviews-correctly',
#   'title': 'Swift - UIStackView not displaying subviews correctly'},
#  {'tags': ['gcc', 'fortran', 'cygwin', 'gfortran'],
#   'owner': {'account_id': 22255553,
#    'reputation': 1,
#    'user_id': 16487776,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/5e3b6b7411690fd0f5c9e031ad6f37d2?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'liammo29',
#    'link': 'https://stackoverflow.com/users/16487776/liammo29'},
#   'is_answered': False,
#   'view_count': 18,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457602,
#   'creation_date': 1659454158,
#   'last_edit_date': 1659457602,
#   'question_id': 73210104,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210104/legacy-error-in-fortran-compiler-error-legacy-extension-real-array-index-at',
#   'title': 'legacy error in fortran compiler &quot;Error: Legacy Extension: REAL array index at (1)&quot;'},
#  {'tags': ['reactjs', 'amcharts', 'storybook'],
#   'owner': {'account_id': 14138833,
#    'reputation': 9,
#    'user_id': 10214305,
#    'user_type': 'registered',
#    'profile_image': 'https://lh4.googleusercontent.com/-tjU0oVdCojM/AAAAAAAAAAI/AAAAAAAAAAc/ygB09KMSR9Y/photo.jpg?sz=256',
#    'display_name': 'Try Something New',
#    'link': 'https://stackoverflow.com/users/10214305/try-something-new'},
#   'is_answered': False,
#   'view_count': 11,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457599,
#   'creation_date': 1659455512,
#   'last_edit_date': 1659457599,
#   'question_id': 73210392,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210392/is-there-a-way-to-implement-mouse-hover-in-amcharts-javascript-library',
#   'title': 'Is there a way to implement mouse hover in amCharts javascript library?'},
#  {'tags': ['python', 'pandas', 'dataframe'],
#   'owner': {'account_id': 23596625,
#    'reputation': 121,
#    'user_id': 17633664,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJwU3KhIFLWZ-m-gUZbpYYO1CuFt7P6ATW5jzZ-e=k-s256',
#    'display_name': 'Pren Ven',
#    'link': 'https://stackoverflow.com/users/17633664/pren-ven'},
#   'is_answered': True,
#   'view_count': 25,
#   'accepted_answer_id': 73210538,
#   'answer_count': 3,
#   'score': 0,
#   'last_activity_date': 1659457598,
#   'creation_date': 1659455464,
#   'question_id': 73210381,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210381/drop-rows-based-on-conditions-and-create-new-columns-of-pandas-dataframe',
#   'title': 'Drop rows based on conditions and create new columns of pandas dataframe'},
#  {'tags': ['neovim', 'openbsd'],
#   'owner': {'account_id': 16477377,
#    'reputation': 385,
#    'user_id': 12283863,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/sNtbo.png?s=256&g=1',
#    'display_name': 'Rawley Fowler',
#    'link': 'https://stackoverflow.com/users/12283863/rawley-fowler'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457597,
#   'creation_date': 1659457597,
#   'question_id': 73210790,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210790/how-to-tell-if-current-operating-system-is-openbsd-in-neovim',
#   'title': 'How to tell if current operating system is OpenBSD in NeoVim?'},
#  {'tags': ['python', 'openvino'],
#   'owner': {'account_id': 13872349,
#    'reputation': 45,
#    'user_id': 10015076,
#    'user_type': 'registered',
#    'profile_image': 'https://lh4.googleusercontent.com/-rqtMbtYB8CI/AAAAAAAAAAI/AAAAAAAAAAA/AB6qoq2WaOrTQFLyyg3gzhGpWZCK9LRGNg/mo/photo.jpg?sz=256',
#    'display_name': 'Pradyumn Pathak',
#    'link': 'https://stackoverflow.com/users/10015076/pradyumn-pathak'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457595,
#   'creation_date': 1659457102,
#   'last_edit_date': 1659457595,
#   'question_id': 73210695,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210695/openvino-optimised-model-ignores-few-labels-while-inferencing',
#   'title': 'OpenVino Optimised model ignores few labels while inferencing'},
#  {'tags': ['excel', 'vba'],
#   'owner': {'account_id': 25575320,
#    'reputation': 37,
#    'user_id': 19354916,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/1caf9f84d1bdf4bdf405132838c52a38?s=256&d=identicon&r=PG',
#    'display_name': 'Wallenbees',
#    'link': 'https://stackoverflow.com/users/19354916/wallenbees'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457581,
#   'creation_date': 1659457581,
#   'question_id': 73210789,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210789/vba-excel-my-borders-arent-printing-correctly-here',
#   'title': 'VBA Excel - My Borders are&#39;nt printing correctly here'},
#  {'tags': ['python', 'hadoop', 'pyspark', 'spark-streaming'],
#   'owner': {'account_id': 11811718,
#    'reputation': 44,
#    'user_id': 8643009,
#    'user_type': 'registered',
#    'profile_image': 'https://lh4.googleusercontent.com/-w2qSAr9cnSg/AAAAAAAAAAI/AAAAAAAAHIo/wJaO13ZHexo/photo.jpg?sz=256',
#    'display_name': 'Muhammad Umer Lari',
#    'link': 'https://stackoverflow.com/users/8643009/muhammad-umer-lari'},
#   'is_answered': False,
#   'view_count': 29,
#   'answer_count': 1,
#   'score': -2,
#   'last_activity_date': 1659457571,
#   'creation_date': 1659422489,
#   'last_edit_date': 1659457571,
#   'question_id': 73203015,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73203015/name-spark-is-not-defined-in-pyspark-spark-version-1-6-3',
#   'title': 'name &#39;spark&#39; is not defined in pyspark (Spark Version 1.6.3)'},
#  {'tags': ['kubernetes', 'google-kubernetes-engine', 'hashicorp-vault'],
#   'owner': {'account_id': 9041471,
#    'reputation': 129,
#    'user_id': 10005028,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/LLMaZ.jpg?s=256&g=1',
#    'display_name': 'RobTheRobot16',
#    'link': 'https://stackoverflow.com/users/10005028/robtherobot16'},
#   'is_answered': False,
#   'view_count': 15,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457570,
#   'creation_date': 1659450139,
#   'last_edit_date': 1659457570,
#   'question_id': 73209201,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73209201/deploying-ha-vault-to-gke-dial-tcp-127-0-0-18200-connect-connection-refused',
#   'title': 'Deploying HA Vault To GKE - dial tcp 127.0.0.1:8200: connect: connection refused'},
#  {'tags': ['visual-studio-code'],
#   'owner': {'account_id': 25959467,
#    'reputation': 1,
#    'user_id': 19676316,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AFdZucpNNNkRAHv3buRnZoyRjLGceBuOfnCO9eVl5g60aQ=k-s256',
#    'display_name': 'Yasser Benhammadi',
#    'link': 'https://stackoverflow.com/users/19676316/yasser-benhammadi'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457568,
#   'creation_date': 1659457499,
#   'last_edit_date': 1659457568,
#   'question_id': 73210780,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210780/vscode-crashes-when-i-open-it',
#   'title': 'VSCode crashes when i open it?'},
#  {'tags': ['json', 'groovy', 'jmeter', 'web-api-testing', 'post-processor'],
#   'owner': {'account_id': 25949811,
#    'reputation': 7,
#    'user_id': 19668037,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/7a0757df50d4ec5c005fad1a614bb283?s=256&d=identicon&r=PG',
#    'display_name': 'thatsmycode',
#    'link': 'https://stackoverflow.com/users/19668037/thatsmycode'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457562,
#   'creation_date': 1659457562,
#   'question_id': 73210788,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210788/how-to-save-json-response-from-api-call-into-json-files',
#   'title': 'How to save json response from API call into json files?'},
#  {'tags': ['machine-learning',
#    'keras',
#    'artificial-intelligence',
#    'transfer-learning'],
#   'owner': {'account_id': 18541719,
#    'reputation': 51,
#    'user_id': 13510057,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/6338d217929fb86d5da608ad14d052ba?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Vortekus',
#    'link': 'https://stackoverflow.com/users/13510057/vortekus'},
#   'is_answered': False,
#   'view_count': 24,
#   'answer_count': 1,
#   'score': -1,
#   'last_activity_date': 1659457559,
#   'creation_date': 1659193574,
#   'last_edit_date': 1659224143,
#   'question_id': 73176713,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73176713/why-is-transfer-learning-using-vgg16-bad-for-image-coloursatinon',
#   'title': 'Why is transfer learning using VGG16 bad for image coloursatinon'},
#  {'tags': ['c++', 'if-statement'],
#   'owner': {'account_id': 17326579,
#    'reputation': 1,
#    'user_id': 12550673,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/b413ad301f2fca3b44738090c7e4b496?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Haroon Bin Raziq',
#    'link': 'https://stackoverflow.com/users/12550673/haroon-bin-raziq'},
#   'is_answered': False,
#   'view_count': 14,
#   'answer_count': 0,
#   'score': -1,
#   'last_activity_date': 1659457557,
#   'creation_date': 1659457325,
#   'last_edit_date': 1659457557,
#   'question_id': 73210741,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210741/a-student-will-not-be-allowed-to-sit-in-exam-if-his-her-attendence-is-less-than',
#   'title': 'A student will not be allowed to sit in exam if his/her attendence is less than 75%'},
#  {'tags': ['python', 'pandas', 'dataframe', 'sparse-matrix', 'fill'],
#   'owner': {'account_id': 25959395,
#    'reputation': 1,
#    'user_id': 19676255,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmltO1GhNfoJMTYR8Q38HFrkpC-AzgfxmcicOj08=k-s256',
#    'display_name': 'Pachita',
#    'link': 'https://stackoverflow.com/users/19676255/pachita'},
#   'is_answered': False,
#   'view_count': 12,
#   'answer_count': 0,
#   'score': -1,
#   'last_activity_date': 1659457557,
#   'creation_date': 1659457319,
#   'last_edit_date': 1659457557,
#   'question_id': 73210740,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210740/fill-sparse-row-of-a-dataframe-with-the-existing-values-in-the-column',
#   'title': 'Fill sparse row of a dataframe with the existing values in the column'},
#  {'tags': ['c', 'buffer', 'fread'],
#   'owner': {'account_id': 20719687,
#    'reputation': 1,
#    'user_id': 16119584,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/CyAcN.jpg?s=256&g=1',
#    'display_name': 'NotYourFox',
#    'link': 'https://stackoverflow.com/users/16119584/notyourfox'},
#   'is_answered': False,
#   'view_count': 15,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1659457552,
#   'creation_date': 1659456907,
#   'last_edit_date': 1659457552,
#   'question_id': 73210660,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210660/c-reading-binary-file-returns-zeros',
#   'title': 'C - Reading binary file returns zeros'},
#  {'tags': ['ssms'],
#   'owner': {'account_id': 25958145,
#    'reputation': 1,
#    'user_id': 19675194,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AFdZucr6-X_9l0oU16U_leXxz6sIc1pv2VArsVC23_kEdA=k-s256',
#    'display_name': 'yadagiri burry',
#    'link': 'https://stackoverflow.com/users/19675194/yadagiri-burry'},
#   'is_answered': False,
#   'view_count': 14,
#   'answer_count': 0,
#   'score': -2,
#   'last_activity_date': 1659457549,
#   'creation_date': 1659448672,
#   'last_edit_date': 1659457549,
#   'question_id': 73208839,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73208839/how-to-test-performance-original-table-vs-partition-table-in-sql-server',
#   'title': 'How to test performance original table vs partition table in SQL Server?'},
#  {'tags': ['python', 'pandas', 'dataframe'],
#   'owner': {'account_id': 21977388,
#    'reputation': 3,
#    'user_id': 16253004,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJwb5MMHb2_K58VJvBTPMgRm8iL3NVZghng3oeLv=k-s256',
#    'display_name': 'Qas',
#    'link': 'https://stackoverflow.com/users/16253004/qas'},
#   'is_answered': False,
#   'view_count': 16,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1659457547,
#   'creation_date': 1659456316,
#   'question_id': 73210556,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73210556/how-to-create-a-bar-graph-for-2-different-variables-in-a-column-in-pandas',
#   'title': 'How to create a bar graph for 2 different variables in a column in pandas'}]

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
for i in results["items"]:
    if "python" in (i["tags"]):
        print(i["title"])
# Out:
# Unique combination/product of two columns from multiple lists in python 3
# running api from postman and using studio 3t for mongo db. in postman getting output error but status is showing ok
# Drop rows based on conditions and create new columns of pandas dataframe
# OpenVino Optimised model ignores few labels while inferencing
# name &#39;spark&#39; is not defined in pyspark (Spark Version 1.6.3)
# Fill sparse row of a dataframe with the existing values in the column
# How to create a bar graph for 2 different variables in a column in pandas

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
for i in results["items"]:
     if "question_id"=="6784" and "question_id"=="6473":
        print('True')
else:
        print("False")
# Out:
# False
